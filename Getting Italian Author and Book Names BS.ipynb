# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
main5 = 'http://www.bibliotecaitaliana.it/indice/visualizza_scheda/bibit00000'
main4 = 'http://www.bibliotecaitaliana.it/indice/visualizza_scheda/bibit0000'
main3 = 'http://www.bibliotecaitaliana.it/indice/visualizza_scheda/bibit000'
main2 = 'http://www.bibliotecaitaliana.it/indice/visualizza_scheda/bibit00'

# %%
list1 = list(range(0,9999))

# %%
len(str(list1[100]))
# Out:
# 3

# %%
links = []

# %%
for i in list1:
    if (len(str(i))) == 1:
        links.append(str(main5+str(i)))
    elif (len(str(i))) == 2:
        links.append(str(main4+str(i)))
    elif (len(str(i))) == 3:
        links.append(str(main3+str(i)))
    elif (len(str(i))) == 4:
        links.append(str(main2+str(i)))

# %%
all_requests = []

# %%
from tqdm import tqdm

# %%
for link in tqdm(links):
    all_requests.append(requests.get(link))
# Out:
# 100%|██████████| 9999/9999 [2:45:05<00:00,  1.04it/s]

# %%
all_requests2 = all_requests

# %%
len(all_requests2)
# Out:
# 9998

# %%
valid_pages = []

# %%
for r in all_requests2:
    if r.status_code == 200:
        valid_pages.append(r)

# %%
soups = []

# %%
for page in valid_pages:
    soup = BeautifulSoup(page.content,'html.parser')
    soups.append(soup)

# %%
authors = []
titles = []

# %%
for soup in soups:
    text_only = [text for text in soup.stripped_strings]
    try:
        author_index = text_only.index('Autore:')
    except:
        pass
    authors.append(text_only[author_index+1])
    try:
        title_index = text_only.index('Titolo:')
    except:
        pass
    titles.append(text_only[title_index+1])

# %%
len(authors)
# Out:
# 1656

# %%
len(titles)
# Out:
# 1656

# %%
titles
# Out:
# ['Tragedia di Antigone',
#  'Rime',
#  'Cena familiaris',
#  'De commodis litterarum atque incommodis',
#  'De pictura [Redazione volgare]',
#  'Epistola consolatoria',
#  'De pictura [Redazione latina]',
#  'Naufragus',
#  'Sentenze pitagoriche',
#  'I libri della famiglia',
#  'Momus',
#  'Vita',
#  'Antigone',
#  'Agide',
#  'Bruto primo',
#  'Bruto secondo',
#  'Agamennone',
#  'De vulgari eloquentia',
#  'Commedia',
#  'Il dedalione o ver del poeta',
#  'Cronica',
#  "Lettere sull'arte",
#  'I suppositi',
#  'Rime',
#  'Satire',
#  'Cinque canti',
#  'Cassaria',
#  'Tragedia di Antigone',
#  'Rime',
#  'Cena familiaris',
#  'De commodis litterarum atque incommodis',
#  'De pictura [Redazione volgare]',
#  'Epistola consolatoria',
#  'De pictura [Redazione latina]',
#  'Naufragus',
#  'Sentenze pitagoriche',
#  'I libri della famiglia',
#  'Momus',
#  'Vita',
#  'Antigone',
#  'Agide',
#  'Bruto primo',
#  'Bruto secondo',
#  'Agamennone',
#  'De vulgari eloquentia',
#  'Commedia',
#  'Il dedalione o ver del poeta',
#  'Cronica',
#  "Lettere sull'arte",
#  'I suppositi',
#  'Rime',
#  'Satire',
#  'Cinque canti',
#  'Cassaria',
#  'Iscrizioni obituarie della cattedrale',
#  'Liber Maiolichinus',
#  'Novella del grasso legnaiuolo',
#  'Della Eloquenza',
#  'Dei delitti e delle pene',
#  'Sonetti',
#  'Prose della volgar lingua',
#  'Asolani',
#  'Poesie politiche e romanze',
#  "Breve considerazione intorno al componimento de la comedia de' nostri tempi",
#  'Rime',
#  'Corbaccio',
#  'Rime',
#  'Teseida',
#  'Filocolo',
#  'Elegia di Madonna Fiammetta',
#  'Caccia di Diana',
#  'Amorosa visione',
#  'Filostrato',
#  'Ninfale fiesolano',
#  'Amorum libri',
#  'Orlando innamorato',
#  'Candelaio',
#  'Prologhi',
#  'Caio Gracco',
#  'Poesie',
#  'Aminta (ms. Campori 491)',
#  'Novellino',
#  'Relazione di Marino Cavalli (1551)',
#  'Re Torrismondo',
#  "Operette morali d'Isocrate",
#  'Polissena',
#  'Discorsi sopra gli uomini illustri di Plutarco',
#  'Expositio Herculis Furentis',
#  'Così fan tutte',
#  "Relazione dell'ambasceria straordinaria in Francia (1643)",
#  'Studii di bibliografia analitica',
#  'Rime',
#  'Notizie istoriche e geografiche sulla città e chiesa arcivescovile di Damiata',
#  'Carteggio',
#  'Rime',
#  'Rocta facta per Duca die ferrara ala bastia',
#  'Endimione',
#  'Poesie',
#  'Frammenti autobiografici',
#  "Relazione d'Austria",
#  "L'Archivio della Letteratura Italiana e la Biblioteca Nazionale Centrale di Firenze",
#  'Cronica di Ferrara, volgarizzamento della Cronica Parva di Riccobaldo',
#  'Relazione di Francia',
#  'Orazioni',
#  'Chrysis',
#  "La rappresentazione di Moisè e Faraone re d'Egitto",
#  'Le avventure di Saffo',
#  "Alcuni documenti che testimoniano i rapporti tra Pisa e l'Oriente tra la fine del XIII e l'inizio del XIV secolo",
#  'Poesie',
#  'Poesie',
#  'Rime',
#  'Relazione di Francia di Alvise Mocenigo',
#  'Discorso sopra la Batracomiomachia',
#  'Senilità',
#  'Saggio sopra gli errori popolari degli antichi',
#  'La città felice',
#  'Lettere  di un prete modernista',
#  'De dilectione regnantium',
#  'Vita dei campi',
#  "Expositione sopra l'«Inferno» di Dante Alligieri",
#  'Relazione di Spagna (1559)',
#  'Dialogo del reggimento di Firenze',
#  'An vulgus et literati eodem modo per Terentii Tullique tempora Romae locuti sint',
#  'Epistolario',
#  'Rime',
#  'Gride fatte pubblicare da Lodovico Ariosto ducale commissario generale in Garfagnana',
#  'Trattatello in laude di Dante',
#  'Alcune poesie di Ripano Eupilino',
#  'Epigrammi',
#  "Manifesti e annuncio bibliografico di un'edizione delle opere di Cicerone",
#  'Scritti vari',
#  'Contra eum qui maledixit Italiam',
#  "Descrizione di Pisa fatta da Vincenzo Pitti l'anno 1616",
#  'Il governo e le biblioteche',
#  'La psicologia come scienza positiva',
#  'Poesie latine',
#  'Alcuni documenti relativi ai rapporti economici tra la Sardegna e Pisa nel Medioevo',
#  'Istoria',
#  'Volgarizzamento del De viribus herbarum di Macer Floridus',
#  'La palingenesi politica',
#  'Il Costante overo de la Clemenza',
#  'La via del rifugio',
#  'Crestomazia italiana (Poesia)',
#  'Cabala del cavallo pegaseo',
#  'Relatione de S. Alvise Contarini Kr. (1650)',
#  'Poesie',
#  'Poesie di Ossian',
#  'Una vita',
#  'Timone',
#  'Contrasti in ottava rima improvvisati da Vasco Cai da Bientina',
#  'Genealogia della Serenissima casa Gonzaga',
#  "Cleopatra e Marc'Antonio Tragedia",
#  'Tre lezioni sulla poetica',
#  'Rime',
#  'Della vera poetica',
#  'Odi barbare',
#  'Giambi ed Epodi',
#  "Breve et ingenioso discorso sopra l'opera di Dante",
#  "Historie dell'antichissima città di Pisa",
#  'Il libro del Cortegiano',
#  "Storia d'Italia",
#  'Vita',
#  'Relazione di Francia di Andrea Gussoni e di Agostino Nani (1610)',
#  'Le avventure di Pinocchio',
#  'Cronica',
#  'Tutte le poesie',
#  'Della oratoria e poetica facoltà',
#  'Le piacevoli e ridicolose simplicità di Bertoldino',
#  'De Arte Poetica',
#  'Il viandante',
#  'La flagellazione',
#  "Parere su l'ufficio degl'Ispettori degli studi",
#  'De Eloquentia dialogus',
#  'Due Discorsi',
#  'Rime',
#  'Le sottilissime astuzie di Bertoldo',
#  'Relazione di Germania (1564)',
#  'Pisa illustrata nelle arti del disegno',
#  'Il canto della fanciulla',
#  'Pisa illustrata nelle arti del disegno',
#  'Capitoli',
#  'Poesie',
#  'Rime',
#  'Rime rifiutate',
#  'Comentum super poema Comedie Dantis (III red.)',
#  'Il Trecentonovelle',
#  'Rime',
#  'Una delle ultime sere di carnovale',
#  'Dissertazione sopra le virtù intellettuali',
#  'Scritti sul Boccaccio',
#  'Poesie',
#  'Il palazzo Turchi-Trotti-Di Bagno: Elenco degli ambienti e dei quadri presenti nel palazzo al 1622 (Parte I)',
#  'Poesie',
#  'Il Gierusalemme',
#  "L'asino",
#  'La Navigazione di San Brandano',
#  'Presentazione delle Canzoni (Nuovo Ricoglitore, 1825)',
#  'Canzoni (ed. Roma 1818)',
#  'Componimenti poetici (1810)',
#  'I partiti anarchici in Italia',
#  "Discorso intorno a que' principii, cause et accrescimenti che la comedia, la tragedia et il poema eroico ricevono dalla filosofia morale e civile e da'governatori delle republiche",
#  "Breve trattato dell'oratore",
#  'Poesie italiane',
#  'Mirzia',
#  'Clizia',
#  "El libro dell'amore",
#  'Ragionamenti',
#  'Piccolo mondo moderno',
#  'Tieste',
#  'Dei Sepolcri',
#  'Le Grazie',
#  'Dialogo sopra i due massimi sistemi',
#  'Poesie',
#  'Del furor poetico',
#  'Dissertazione sopra la logica universalmente considerata',
#  'Poesie',
#  'Difesa della lingua italiana',
#  'De principiis rerum, elementis et causis',
#  'De la purgatione della tragedia',
#  'Epistolario (1816-1818)',
#  'Poesie',
#  'Diario del primo amore',
#  'Relazione della China',
#  'Volgarizzamento della Dissuasio Valerii',
#  'Poesie',
#  'Vita scritta da lui medesimo',
#  'Dello scopo di Gregorio VII',
#  "Dell'imitazione",
#  "Risposta alle opposizioni d'incerto fatte al sonetto in morte di Pietro Spino",
#  'Relazione di Francia di Francesco II Morosini (1752)',
#  'Poesie',
#  'Don Giovanni',
#  'Relazione di Germania',
#  'Lo Inferno della Commedia di Dante Alighieri col comento di Guiniforto delli Bargigi',
#  'Liber Johannis de Ravenna de primo eius introitu ad aulam',
#  'Rosmunda',
#  'Il Fiore',
#  'Il Principe',
#  'Codice sul volo degli uccelli',
#  'Don Garzia',
#  'Della Monarchia rappresentativa in Italia',
#  'Poesie',
#  'Cinque sentenze emanate dai tribunali di Pisa nel XII secolo',
#  "Chiose all' Inferno",
#  'Lettera apologetica',
#  'Rationarium vite',
#  "Dialogo dell'imprese militari e amorose",
#  'Lettera a Bernardo Tasso',
#  'Poesie',
#  'Il Gianluca overo delle Maschere',
#  'De lingue latine differentiis',
#  'Canti di Castelvecchio',
#  'Pisa e le sue adiacenze...',
#  'Relatione di Germania (1638)',
#  'Maria Stuarda',
#  'I Suppositi (red. in versi)',
#  'Poesie',
#  'La civil conversazione',
#  'De la condizione di Venezia',
#  'Rime',
#  'Rime',
#  'Poesie',
#  "Dialoghi d'Amore",
#  'Discorso dei costumi degli italiani',
#  'Leporeambi',
#  "Dialoghi dell'invenzione poetica",
#  'Della divisione del lavoro in attribuzioni maschili e femminili',
#  'Capitoli',
#  'Per S. A. don Pietro Vigilio',
#  "Sul Romanticismo. Lettera al marchese Cesare D'Azeglio",
#  "Libro de M. Ludovico Ariosto commissario in Garfagnana dato a' dì 26 de zenaro 1526",
#  'Fabula de Cefalo',
#  'Le canzoni di re Enzio',
#  'Stanze in lode di Angela Serena',
#  'Le iscrizioni celebrative della facciata del Duomo',
#  'Intermedi',
#  'La riforma cattolica',
#  'Epystole familiares',
#  'Rime eteree',
#  "Versi d'amore",
#  'Poesie',
#  'La rappresentazione della purificazione',
#  'Gerusalemme conquistata',
#  'Libro, biblioteche e associazioni bibliotecarie',
#  'Se stata fosse a ti toa fama rara',
#  "Un memoriale ad Alfonso d'Aragona",
#  'Christus meus',
#  "L'intelligenza della folla",
#  'Poesie giovanili',
#  'Decameron',
#  'Relazione di Francia di Nicolò Foscarini e Lorenzo Tiepolo (1723)',
#  'Poesie',
#  'Essays on Petrarch',
#  'Sulla lingua italiana. Lettera a Giacinto Carena',
#  'Ode',
#  'Osservazioni sulle dottrine morali di Spinoza',
#  "Sulla traduzione dell'Odissea",
#  'Poesie',
#  "Dell'ufficio del Bibliotecario",
#  'Lo schiavo liberato',
#  'Rime',
#  "La rappresentazione di Josef, di Jacob e de' fratelli",
#  'La festa della natività di nostro signore Gesù Cristo',
#  'Epistolario (1794-1804)',
#  "Dissertazione sopra l'origine, e i primi progressi dell'astronomia",
#  'Poesie',
#  'Canzoniere italiano inedito del sec. XIV (Beinecke Phillips 8826)',
#  "Dissertazione sopra l'estensione",
#  'Ricordi',
#  'Scritti sulle Isole Ionie',
#  'Attilio Regolo',
#  'Sopra due voci italiane',
#  'A un vincitore nel pallone',
#  'Didone abbandonata',
#  'Nuova cronica',
#  'Dissertazione sopra la gravità',
#  "Giudizio d'una tragedia di Canace e Macareo",
#  'Il Cataneo overo de gli idoli',
#  'Nel Circolo Costituzionale di Milano',
#  'Rainaldo e Lesengrino (versione dei Memoriali bolognesi)',
#  'De remediis utriusque fortune',
#  'Il gentilhuomo',
#  'Raguaglio su Pisa',
#  "Pensieri d'amore",
#  'Epistolario. Lettere dal 1803 al 1832',
#  'Sonetti dei mesi',
#  'Istorie fiorentine',
#  'Dragmalogia Johannis de Ravenna de Eligibili Vite Genere',
#  'Trattato di architettura',
#  'Poesie',
#  'Poesie',
#  'Amator',
#  'La Merope',
#  'Epistole',
#  'Bucolica',
#  'Il palazzo Turchi-Trotti-Di Bagno. Elenco dei quadri presenti nel palazzo al 1572',
#  'Poesie',
#  "L'Ermenegildo",
#  'Canis',
#  'Regole della lingua fiorentina',
#  'Orlando Furioso 1521',
#  'Poesie',
#  'Disegni letterari',
#  'Lettera ad Alphonse de Lamartine',
#  "Storia di un'anima",
#  'Rime',
#  'Commentario della battaglia di Marengo',
#  'Relazione di Francia di Alvise Contarini (1634-1637)',
#  'Ragionamento sulla poesia',
#  'Prose varie (1809)',
#  'Le Chiose Cagliaritane',
#  "Esperimento di traduzione dell'Iliade di Omero",
#  'Memorie autobiografiche',
#  "Premessa all'ultimo canto di Saffo",
#  'Avertimenti nel poetare',
#  'Apologeticus',
#  "Alcune considerazioni intorno all'allegoria",
#  'Polinice',
#  'Canzoni e altre rime',
#  'La sampogna',
#  'Epystole seniles',
#  'Relatione de S. Giovanni Grimani',
#  'Poesie sparse',
#  'Aggiunte alla ragion di stato',
#  'Poesie',
#  'Tirsi',
#  'Sommario della Relazione di Germania',
#  'Sonetti',
#  'Canace',
#  'Apologi centum',
#  'Aminta (ms. 1197)',
#  "Per la istituzione d'un teatro civico",
#  'Cristo raffigurato nel sasso',
#  'Relazione di Spagna (1570)',
#  "Agl'Italiani. Orazione in occasione della liberazione del Piceno",
#  'De principe',
#  'Rime',
#  'Traduzione dello Ione platonico',
#  'Dialogo della istitutione delle donne',
#  'Il Libro di messer Tristano (Tristano Veneto)',
#  'Morgante',
#  'Poesie',
#  'Cinquanta nuovi sonetti in vernacolo pisano',
#  "Il libro degli affari proprii di casa de Lapo di Giovanni Niccolini de'Sirigatti",
#  'Relazione di Germania (1692)',
#  'Proemio al libro III dei Libri della famiglia',
#  'Idilli e volgarizzamenti di alcuni versi morali dal greco (',
#  'Rappresentazione di san Giovanni e Paolo',
#  'La Campagna',
#  'Sansone (1809)',
#  'Bibbia Istoriata Padovana della fine del trecento',
#  'Relazione di Francia di Vincenzo Gussoni (1616-1617)',
#  'Della morale letteraria',
#  'De gestis Cesaris',
#  'Mordentius et de Mordentii circino',
#  'Descrizione del Serraglio del Gransignore',
#  'Sonetti inediti',
#  'Pastorale',
#  'Un argomento ad personam',
#  'Allegoria mitologica',
#  'Rime degli Arcadi, tomo quinto',
#  'Rime',
#  "Il palazzo Turchi-Trotti-Di Bagno.Elenco degli ambienti e dei quadri all'interno del palazzo del 1813",
#  'Poesie',
#  'Siroe',
#  'Tullia',
#  'De viris illustribus',
#  'Risposta di Roma a Plutarco',
#  'Epistola a Sforza Secondo',
#  "L'Isole piu famose del mondo",
#  'Epistole Senili (trad. Fracassetti)',
#  'Rime boscherecce',
#  'Telesilla',
#  'Epistolario (1819-1821)',
#  'Dissertazione sopra la felicità',
#  'De montibus, silvis, fontibus, lacubus, fluminibus, stagnis seu paludibus, et de diversis nominibus maris',
#  'Eva',
#  "L'unità dell'Italia e la quadratura del circolo",
#  'Relazione di Francia (1676)',
#  "Relazione di Francia di Nicolo' Erizzo (1695-1699)",
#  "Epistole d'Ovidio",
#  'Ipermestra',
#  'Sonetti e canzoni',
#  'La clemenza di Tito',
#  'Della fama di Orazio presso gli antichi',
#  'I dilettevoli dialogi, le vere narrationi, le facete epistole di Luciano filosofo',
#  'Poesie minori (versi giovanili e altre poesie)',
#  'Relazione di Costantinopoli (1682)',
#  'In morte di Ugo di Bassville',
#  'Regole grammaticali della volgar lingua',
#  'Aristodemo',
#  'De duobus amantibus historia',
#  'Poesie',
#  'La Divina Commedia di Dante Alighieri postillata da Torquato Tasso',
#  'I rusteghi',
#  "Sesto tomo dell'io",
#  'Relazione di Daniele Dolfin, 1793',
#  "Dei doveri dell'uomo",
#  'Erbolato',
#  'Poesie',
#  "Discorso dell'arte del dialogo",
#  'Gli Eudemoni',
#  'Lettere',
#  'Linguaccio',
#  'Poesie',
#  'Fermo e Lucia',
#  'Dialogo sopra la nobiltà',
#  'Rime',
#  'Epystole metrice',
#  'Pensieri',
#  'Della moralità delle opere tragiche',
#  'Relazione di Piamonte',
#  'De nuptjis Batibecho et Seraboca',
#  'Rime',
#  'De magia mathematica',
#  'Disperata rimembranza',
#  'Strambotti',
#  "Dissertazione sopra l'astronomia",
#  'Poesie',
#  'Da cuspide ferrate',
#  'Ioannis Pici Mirandulae Vita',
#  'Il giorno (2 redazione)',
#  'Dissertazione sopra le virtù morali in particolare',
#  'Notizia intorno a Didimo Chierico',
#  'De architectura Lulliana',
#  'La Legenda de Sancto Stady',
#  'Opere minori',
#  'Ajace',
#  'Poesie',
#  'Epistolario (1815-1816)',
#  "Massime essenziali dell'Impero Ottomano",
#  'Libri physicorum Aristotelis explanati',
#  'Epistolario',
#  'Il sacrificio (1587)',
#  'Poesie',
#  'Poesie',
#  'De dignitate et excellentia hominis (I-II)',
#  'Sofonisba',
#  'Paralipomeni della Batracomiomachia',
#  "I conservatori e l'evoluzione naturale dei partiti politici in Italia",
#  'Rime',
#  'Canti (ed. Napoli 1835)',
#  'Relazione di Germania (1682)',
#  'Relazione di Germania (1678)',
#  'Sonetti in persona di ser Pecora fiorentino beccaio',
#  'De vita solitaria',
#  'Per la passione di Nostro Signore',
#  'Il Forno overo de la Nobiltà',
#  'Cronica deli Imperadori',
#  'De laboribus Herculis',
#  'Mirra',
#  'Poesie',
#  'De umbris idearum',
#  'Vita scritta da se medesimo',
#  'Comedia di Malpratico',
#  'I promessi sposi [redazione 1827]',
#  'Issipile',
#  "Argomento di una Canzone sullo stato presente dell'Italia",
#  'Il Cataneo overo de le conclusioni amorose',
#  'Relazione di Germania (1659)',
#  'Postulati etici e imperativo categorico',
#  'Memorie',
#  'Posteritati',
#  'Rime',
#  'Poesie',
#  "Dissertazione sopra l'esistenza di un ente supremo",
#  'Esercitazioni latine (1809)',
#  'Poesie',
#  'Rime',
#  'Poesie',
#  'Paola da Buti',
#  'Viaggio in Terrasanta',
#  "Dell'unità della favola",
#  'Poesie',
#  'Trattato della poesia lirica',
#  "L'eroe cinese",
#  'Passion',
#  'Rolandin',
#  'Rime disperse e attribuite',
#  "L'avete fatta a me",
#  'Processi verbali',
#  'Uxoria',
#  'Rime',
#  'Il Milione veneto',
#  "Relazione della visita fatta all'ufizio de fossi di Pisa l'anno 1740",
#  'I sistemi e la democrazia. Pensieri',
#  'Theogenius',
#  'Secretum',
#  'Poesie',
#  'Vita nuova',
#  'Rime e ritmi',
#  'Poesie varie',
#  'Sermone sul dì del giudizio',
#  'Rime degli Arcadi, tomo quarto',
#  'Relazione di Germania (1658)',
#  'Istoria del Concilio tridentino',
#  'Oratio consolatoria',
#  'Le lagrime di Cristo',
#  'Musca',
#  'De porcaria conjuratione',
#  'Parere sopra il Salterio ebraico',
#  'Rime degli Arcadi, tomo terzo',
#  'La rotta e presa fatta a bresa per li francesi',
#  'Dissertazione sopra la luce',
#  "Dell'arte della guerra",
#  'Profugiorum ab aerumna libri III',
#  'Fosca',
#  "Varie avvertenze utili, e necessarie agli amatori de' buoni libri",
#  'Medicina Lulliana',
#  'Varianti della Gerusalemme Liberata',
#  'Selva',
#  'Poesie',
#  'Achille in Sciro',
#  'Geste francor',
#  'Il giorno (1 redazione)',
#  'Epistole entomologiche',
#  'I limiti del razionalismo etico',
#  'Rime',
#  "Dedica all'Orbecche",
#  'Avemaria',
#  'Relazione di Germania',
#  'Orlando Furioso 1516',
#  'Vita di Castruccio Castracani',
#  'Novella di Belfagor',
#  "Gl'innamorati",
#  'Poesie',
#  'Conclusioni amorose',
#  "Sull'indole del piacere e del dolore",
#  'Relazione di Germania (1725)',
#  'Della Politica nella presente civiltà. Abbozzi.',
#  'Discorso sopra Mosco',
#  'Rime',
#  'Orbecche',
#  'Novella del buon vecchio e della bella fanciulla',
#  'Spirto gentil, da quel bel grembo sciolto',
#  'Poesie in ottava rima',
#  'Storia di una capinera',
#  'Il Negromante',
#  'Testi toscani di carattere pratico',
#  'Appunti per Spartaco',
#  'Cantici di Fidenzio',
#  'Studi su Dante pubblicati sulla Edinburgh Review',
#  'Quaternuccio e giornale B (1459-1485)',
#  'Il Beltramo overo de la Cortesia',
#  "Discorsi dell'arte poetica",
#  "Del rinnovamento civile d'Italia",
#  "La congiura de' Pazzi",
#  'Delle differenze poetiche, per risposta al signor Orazio Ariosto',
#  'A una fanciulla',
#  'Arringhe',
#  "Ragionamento d'Isocrate a Filippo",
#  'Poesie',
#  'De verbis romanae locutionis',
#  'Grida del 23 aprile 1435',
#  'Relazione di Germania (1557)',
#  'Poesie',
#  'Della ragione di stato',
#  'Discorso intorno allo Stato della Chiesa',
#  'Il N. overo de la Pietà',
#  'Rime',
#  'Elegie',
#  'Il Malpiglio overo de la Corte',
#  'Consolatio ad Donatum',
#  'Saggio di una nomenclatura botanica',
#  'Esperimento sopra i principi della letteratura',
#  "Frammenti di un libro d'avanzo",
#  'Rime',
#  'Epistolario. Lettere dal 1833 al 1853',
#  'Gesta Triumphalia per Pisanos Facta',
#  'De dictis et factis Alphonsi regis',
#  'Poesie',
#  'Relazione di Germania (1685)',
#  'Sonetti',
#  'Scherzi epigrammatici',
#  'Satire',
#  'Relazione di Germania (1630)',
#  'Collatio inter Scipionem, Alexandrum, Hanibalem et Pyrrum',
#  'Primi poemetti',
#  'Il conte di Carmagnola',
#  'Poesie di Mosco',
#  'Canti Carnascialeschi del Rinascimento',
#  'De Canaria',
#  'Il libro dei bilanci di una azienda mercantile del Trecento',
#  'La guerra dei topi e delle rane (1815)',
#  'Della ragione di stato (1598)',
#  'Il Galateo',
#  'Adelchi',
#  'Don Candeloro e C.',
#  'Il manoscritto H',
#  'Relazione di Francia',
#  'Dissertazione sopra la percezione, il giudizio, e il raziocinio',
#  'Deifira',
#  "L'oplomachia pisana, ovvero la battaglia del ponte di Pisa",
#  'Canzonette',
#  'Crudo mar',
#  'Sopra un sepolcro aperto da un aratore',
#  'Vita s.mi fratris Petri Damiani',
#  'Rimatori bolognesi del 300',
#  'Per il Giorno delle Ceneri',
#  'Postulati etici e postulati metafisici',
#  'Sommario della Relazione di Germania',
#  'Poesie',
#  'I postulati della scienza positiva ed il diritto penale',
#  'Endimione',
#  'De triplici minimo et mensura',
#  "Pagine d'arte sparse originali e tradotte",
#  'Laude',
#  "Discorso intorno alla sedizione nata nel Regno di Francia l'anno 1585",
#  'Volgarizzamento del Liber de doctrina loquendi et tacendi di Albertano da Brescia',
#  'La sposa persiana',
#  'Logica',
#  'Relazione di Costantinopoli (1616)',
#  'Dialoghi',
#  "Il Manso overo de l'Amicizia",
#  "Il Ghirlinzone overo l'Epitafio",
#  'Statuti Capitoli et Constitutioni del Ordine de Cavalieri di Santo Stephano, fondato e dotato dal Illustr. et Eccell. Signor Cosimo Medici Duca di Fiorenza e Siena',
#  'Poemi conviviali',
#  'Epistolario',
#  'Lo cunto de li cunti',
#  'La Spagna',
#  'La discesa dei barbari',
#  'Psicologia delle menti associate',
#  'Della coltivazione',
#  'La galeria',
#  'Vita S. Potiti',
#  'La rappresentazione quando Gesù resucitò Lazero',
#  'Summa terminorum metaphysicorum',
#  "Dissertazione sopra le doti dell'anima umana",
#  'Dialogo',
#  'Edmenegarda',
#  'Relazione di Germania (1690)',
#  'Il Belluzzi, o vero la città felice',
#  'Promessi Sposi',
#  'Animadversiones in lampadem Lullianam',
#  'Comento di Cristophoro Landini Fiorentino sopra la Comedia di Dante Alighieri poeta Fiorentino',
#  'Per il progetto di un codice militare disciplinare',
#  "Relazione dell'ambasceria straordinaria in Francia (1617)",
#  'Madrigali',
#  'Genealogie deorum gentilium libri',
#  'Le lettere di Gilio de Amoruso',
#  'Egle (Editio Princeps)',
#  "Traduzione dell'Iliade",
#  'Discorsi intorno alla tragedia',
#  'Poesie',
#  'Il Messaggiero',
#  'Carmina',
#  'Sofonisba',
#  "Rime d'amore secondo il codice chigiano",
#  'Salmi',
#  'Discorso sopra il Parere fatto dal signor Francesco Patricio in difesa di Lodovico Ariosto',
#  'Il palazzo Turchi-Trotti-Di Bagno.Elenco dei libri presenti nella libreria del palazzo al 1622 (Parte II)',
#  'Testi veneziani del Duecento e dei primi del Trecento',
#  'Relazione di Spagna',
#  'La politica di Tommaso Campanella',
#  'La Canterina',
#  'Le Chiose Ambrosiane alla Commedia',
#  'Rime',
#  "Commento all'Inferno di Dante",
#  'Relazione di Francia di Angelo Badoer (1603-1605)',
#  'Inni e Odi',
#  'Le poesie liriche',
#  'Poesie',
#  'Scritti su Parga',
#  'Poesie',
#  'Il sacrificio (1555)',
#  'Estratti dalla Poetica di Lodovico Castelvetro',
#  'Protesta',
#  'Nuovi canti carnascialeschi del Rinascimento',
#  'Rosmunda',
#  'Relazione di Costantinopoli (1684)',
#  'Poesie',
#  "Della eredità di Cleonimo. Orazione d'Iseo",
#  'Poeti del Duecento',
#  'Poesie',
#  'Gesta Ferdinandi regis Aragonum',
#  'Poesie',
#  "Avviso per la traduzione dell'Essai sur l'indifférence en matière de religion dell'abate Lamennais",
#  'Sentir messa',
#  'Saul',
#  'Grida del 20 ottobre 1424',
#  'Le imagini dei Dei de gli Antichi',
#  'Ragionamento sopra la proprietà delle imprese',
#  'Già languiva la notte',
#  'Lettera sovra il comporre le satire atte alla scena',
#  'La idropica',
#  'Dissertazione sopra il moto',
#  'Rime',
#  'Tre croci',
#  "Della reppubblica de' Viniziani",
#  'Rime',
#  "Dell'origine e dell'ufficio della letteratura",
#  "Proemio all'Archivio glottologico italiano",
#  'Zenobia',
#  'La Lena',
#  'Inventario',
#  'Le biblioteche universitarie',
#  'La Feroniade',
#  'Dialogo de la partita soa',
#  'Comedia delle ninfe fiorentine',
#  'Nuovi poemetti',
#  'Rime',
#  'Lettere poetiche',
#  'Il libro delle rime',
#  'Sopra una staffilata del Monti ai Romantici',
#  'Le Metamorfosi di Ovidio',
#  'Amore prigioniero',
#  'Rime',
#  'Discorsi sopra la prima Deca di Tito Livio',
#  'Ah! troppo è ver',
#  "La Molza overo de l'Amore",
#  'Statuta novissima',
#  'Poesie',
#  "L'istituzione dell'uomo",
#  "Dell'indipendenza dell'Italia",
#  'Precetti della poetica',
#  'Manuale di Epitteto',
#  'Frammenti e rime extravaganti',
#  'Componimenti poetici (1809)',
#  'Degli effetti della fame',
#  'Levia Gravia',
#  'Canzoniere',
#  'Poesie',
#  "Presso un rivo ch'avea",
#  'Aminta',
#  'Edippo',
#  'Rime',
#  'Dialogo delle lingue',
#  'Comedia di Dante degli Allagherii col commento di Jacopo di Giovanni dalla Lana bolognese',
#  'Carmina varia',
#  'Relazione di Germania',
#  'Elegie',
#  'Collatio laureationis',
#  'La Chanson de Roland (testo franco-italiano)',
#  'Arbitrato',
#  'Prolegomeni a una morale distinta dalla metafisica',
#  'Rime lugubri',
#  'Noze de Psiche e Cupidine',
#  'Relazione di Giovanni Soranzo dalla Spagna (1565)',
#  'Le femmine puntigliose',
#  'Delle cause della grandezza e magnificienza delle città',
#  'Saggio storico sulla rivoluzione napoletana del 1799',
#  'Acrotismus Camoeracensis',
#  'Poesie',
#  'Lettere alla moglie Margherita',
#  'Trattato del sublime',
#  'La rappresentazione di San Giovanni Battista quando fu decollato',
#  'Trattato della Dignità',
#  'Lettera ai Sigg. compilatori della Biblioteca Italiana in risposta a quella di Mad. la baronessa di Staël Holstein ai medesimi',
#  'Che numero di gente facesse Roma nel colmo della sua grandezza',
#  'Relazione di Germania (1671)',
#  'Poesie',
#  'Ad Arimane',
#  'Della libertà cattolica',
#  'Viaggio in Terrasanta',
#  "Relazione d'Austria",
#  'Lettera ad Antonio Cesari',
#  'Canzoniere',
#  'Il Pastor fido',
#  'Esposizioni sopra la Commedia di Dante',
#  "Inno ai Patriarchi o de' principii del genere umano",
#  'La Cecaria',
#  'Pontifex',
#  'Eros',
#  "Sopra la ricchezza della lingua italiana ne' termini militari",
#  "L'animo della folla",
#  'Rime degli Arcadi, tomo primo',
#  'Egloghe',
#  'Poesie',
#  'Discorso primo: qual sia il fine della poesia in generale',
#  'Su la pluralità dei postulati di valutazione morale',
#  'Gli esuli tebani',
#  'Fragmenta historiae pisanae pisana dialecto conscripta...',
#  'Invective in Laurentium Vallam',
#  "A Bonaparte: dedica dell'oda",
#  "Dissertazione sopra l'elettricismo",
#  'Adriano in Siria',
#  'Le rime del codice isoldiano',
#  'La Cassaria (red. in versi)',
#  "Osservazioni sulla morale cattolica, appendice al cap. III: Del sistema che fonda la morale sull'utilità",
#  'Poesie',
#  'Il Milione',
#  'Carta de logu',
#  'Fragmenta Commentarii super Comoediam Dantis Aldigherii',
#  'Ricordi',
#  "Commento sopra una canzone d'amore di Girolamo Benivieni",
#  'Constitutum legis pisanae civitatis',
#  'Il monte Oliveto',
#  'Libro di ricordi',
#  'Psiche',
#  'De viris illustribus (liber II)',
#  "Il metodo dell'economia pura nell'etica",
#  'Filippo',
#  'Sonetto del signor Torquato Tasso al cavaliere Ercole Cato con la interpretazione e comento del medesimo autore',
#  'La previsione dei fatti sociali',
#  'Le Notti Puniche',
#  'Il barcheggio',
#  'Della ragione di stato',
#  "Dell'educare la gioventù italiana",
#  "In difesa dell'orazione inaugurale",
#  'Sonetti',
#  'Nitteti',
#  'Tre lettere',
#  'Silva',
#  'Bucolicum carmen',
#  'Discorso di un italiano intorno alla poesia romantica',
#  'Sofrona',
#  'Il Forestiero napolitano overo de la Gelosia',
#  'Canti',
#  'Pharsale',
#  "Dissertazione sopra gli attributi, e la provvidenza dell'essere supremo",
#  'Relazione di Costantinopoli (1612)',
#  "Istorietta amorosa fra Leonora de' Bardi e Ippolito Bondelmonti",
#  "Cos'è il modernismo?",
#  'Discorsi del poema eroico',
#  'Berta e Milon',
#  'Poesie',
#  'Rime',
#  'Per la dimostrazione della situazione economica della Provincia pisana',
#  "Comento sopra il I canto dell'Inferno",
#  "Risposta all'Accademia della Crusca in difesa del suo dialogo del piacere onesto",
#  'Panfila',
#  'Odi e Inni',
#  'Canzone sulla Grecia',
#  'Relazione di Francia di Giovanni Battista Nani (1644 al 1648)',
#  'Relazione del Concordato',
#  "La famiglia dell'antiquario",
#  'Pensieri di varia filosofia e di bella letteratura',
#  'Poesie',
#  'La chioma di Berenice',
#  'Gramatica ragionata della lingua italiana',
#  'Canzoniere',
#  'Proemi programmatici',
#  'Lettere',
#  'Relazione di Germania',
#  "Saggio di traduzione dell'Odissea",
#  'La letteratura periodica italiana',
#  'Timoleone',
#  'Il fondamento intrinseco del diritto secondo il Vanni',
#  'De iure',
#  "La rappresentazione di San Bernardo d'uno Signore facea rubare le strade",
#  "L'amore prigioniero",
#  "Martirio de' santi padri del monte Sinai e dell'eremo di Raitu composto da Ammonio monaco",
#  'Quando stanco dal corso in grembo a Teti',
#  'Gli amori',
#  'Contenzione di Pluto e Iro',
#  'Collatio coram Johanne rege',
#  'Il ritratto del privato politico cristiano',
#  'Relazione di Germania',
#  'Relatione di S. Girolamo Giustiniani Cavalier (1654)',
#  'Breve Vetus seu Chronica Antianorum Civitatis Pisarum',
#  'Relazione di Giovanni Battista Nani (1659-1660)',
#  'Epistolario. Carteggio A. Manzoni - A.Rosmini',
#  'La Tiorba a Taccone',
#  'Le baruffe chiozzotte',
#  'Itinerarium ad sepulcrum Domini',
#  "Alessandro nell'Indie",
#  'La bottega del caffè',
#  'Il doge Leonardo Donà (1596)',
#  "Battaglie per difesa dell'italica lingua",
#  'Lettere',
#  'Ars grammatica',
#  'Cronica di Pisa',
#  "Il Conte overo de l'Imprese",
#  'Certame coronario',
#  'Con gli occhi chiusi',
#  'Epigrammi',
#  'Posilecheata',
#  'De viris illustribus',
#  'Appressamento della morte',
#  'Poesie',
#  'Egloghe pescatorie',
#  'Novelle porretane',
#  'Relazione di Francia di Angelo Correr (1638-1641)',
#  'Epistole e lettere',
#  "L'amico tradito",
#  'Africa',
#  "Frammento di una traduzione in volgare dell'impresa di Ciro, descritta da Senofonte",
#  'Libro de natura de amore (ms.)',
#  'De specierum scrutinio',
#  'Epistolario. Lettere dal 1854 al 1873',
#  'In difesa del Generale Pino',
#  'Vita sancti Rainerii confessoris de civitate pisana',
#  'Testamentum',
#  'Lamento facto per Zoane Peregrino da Ferrà scriptore, quando el Marchese Nicolò el fieze metere in Castel Vechio de Ferrà, al tenpo de Meser Ziliol in quelo inpresonato',
#  'Materiali estetici',
#  'Le nozze di Figaro',
#  'Caratteri morali di Teofrasto',
#  'Vita di Torquato Tasso',
#  'Poesie',
#  'Expositio L. Annaei Senecae Agamemnonis',
#  "Dell'errore attribuito a Innocenzo per aver dipinto Apollo piuttosto col violino che con la lira",
#  'Vita di Guidubaldo duca di Urbino',
#  'La virtù indiana (1811)',
#  'Poesie',
#  'Relazione di Germania',
#  'Ercole',
#  'Poesie',
#  'Relazione di Spagna (1578)',
#  'La veniexiana',
#  'De mulieribus claris',
#  'Relazione di Germania (1733)',
#  'Storia della letteratura italiana',
#  'La spada di Federico II',
#  'Liber Abaci',
#  'Altre poesie varie',
#  'Discorsi',
#  'La Dirindina',
#  'De imaginatione',
#  'Rime',
#  'Viaggio di Parnaso',
#  'Relazione di Francia (1686)',
#  'Epistola a Lorenzo il Magnifico',
#  'Dialogo de Fortuna',
#  "I Brevi del Comune e del popolo di Pisa dell'anno 1287",
#  'Della lingua italiana. Quinta redazione e appendice.',
#  'Gli amori pastorali di Dafni e di Cloe',
#  'Il primo libro dei madrigali',
#  'Il verrato',
#  'La rivoluzione',
#  'Rinaldo',
#  'Vita',
#  'Vagabondaggio',
#  "Relazione d'Italia",
#  "La rappresentazione della festa de' Magi",
#  'Discorso sopra alcuni punti della storia longobardica in Italia',
#  'Esopo veneto',
#  'Riso de Democrito e Pianto di Eraclito',
#  'Rime',
#  "Doctrina d'acort",
#  'Relazione di Francia (1663-1665)',
#  'Favola pastorale',
#  'Il campiello',
#  'Le biblioteche, una crisi secolare',
#  'Romolo ed Ersilia',
#  'Stanze',
#  'La Rivoluzione francese del 1789 e la rivoluzione italiana del 1859. Saggio comparativo',
#  'Le smanie per la villeggiatura',
#  'Historia nova della ruina de venetiani',
#  'Libreto de tutte le cosse che se magnano',
#  "Dell'imitazion poetica. Libro primo",
#  'Rime extravaganti',
#  'Lezione sopra un sonetto di monsignor della Casa',
#  'Lettera intorno al vocabolario',
#  'Il sogno. Elegia inedita',
#  'Titanomachia di Esiodo',
#  'Rime',
#  'Le Lettere (1497-1521)',
#  'Diario fiorentino',
#  "Della servitù dell'Italia",
#  "L'Arte Poetica di Orazio travestita ed esposta in ottava rima (1811)",
#  "Comento de' miei sonetti",
#  'Il trionfo della Croce',
#  'Discorso su la Italia',
#  'Filosofia della rivoluzione',
#  'Poesie',
#  'Educatione Christiana dei figliuoli',
#  "O mio cor, quanto t'inganni",
#  'Il teatro comico',
#  'Prometeo',
#  "Il Ficino overo de l'Arte",
#  ...]

# %%
soup = BeautifulSoup(data.text,'html.parser')

# %%
movie_containers = soup.find_all('div', class_ = 'books')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 1
